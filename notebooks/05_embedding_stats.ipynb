# %% [markdown]
# # Stage 05 — Embedding Statistics (stub)
#
# Loads all `.npz` embeddings, runs PCA → UMAP, K-Means clustering,
# and plots the 2-D embedding space coloured by cluster / patent metadata.
#
# **Status:** stub — implement `src/embedding_stats.py` before running.

# %%
import sys
from pathlib import Path

repo_root = Path().resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from src.config_loader import load_config
from src.embedding_stats import (
    load_all_embeddings, run_pca, run_umap,
    cluster_kmeans, compute_distribution_stats, plot_umap,
)

cfg = load_config()
proc_dir = cfg['paths']['processed']
print(f"processed: {proc_dir}")

# %%
# TODO: uncomment when embedding_stats.py is implemented
#
# embeddings, labels = load_all_embeddings(cfg)
# print(f"Corpus: {embeddings.shape[0]} images, {embeddings.shape[1]}-dim embeddings")
#
# pca_50  = run_pca(embeddings, n_components=50)
# umap_2d = run_umap(pca_50)
# clusters = cluster_kmeans(pca_50, k=10)
#
# stats = compute_distribution_stats(embeddings)
# print(stats)
#
# fig = plot_umap(umap_2d, clusters, title='eVTOL drawings — DINOv2 UMAP')
# fig.show()

print('Stage 05 not yet implemented — see src/embedding_stats.py')
