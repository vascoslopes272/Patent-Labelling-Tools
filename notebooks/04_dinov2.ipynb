# %% [markdown]
# # Stage 04 — DINOv2 Embeddings (stub)
#
# Loads `facebook/dinov2-base` from HuggingFace, embeds each processed image,
# and saves the CLS-token vectors as compressed `.npz` archives.
#
# **Status:** stub — implement `src/dinov2.py` before running.

# %%
import sys
from pathlib import Path

repo_root = Path().resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from src.config_loader import load_config
from src.dinov2 import load_model, embed_patent, save_embeddings

cfg = load_config()
proc_dir = cfg['paths']['processed']
print(f"model      : {cfg['dinov2']['model']}")
print(f"processed  : {proc_dir}")

# %%
# TODO: uncomment when dinov2.py is implemented
#
# model, processor = load_model(cfg)
#
# for patent_dir in sorted(proc_dir.iterdir()):
#     if not patent_dir.is_dir():
#         continue
#     patent_id = patent_dir.name
#     embeddings = embed_patent(patent_id, cfg, model, processor)
#     dest = save_embeddings(patent_id, embeddings, cfg)
#     print(f"{patent_id}: {len(embeddings)} embeddings saved → {dest.name}")

print('Stage 04 not yet implemented — see src/dinov2.py')
