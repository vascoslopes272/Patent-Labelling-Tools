# %% [markdown]
# # Stage 02 — Processing (stub)
#
# Pads each drawing to a square canvas, then resizes to `processing.target_size` (518×518).
# White padding is added on the shorter axis to preserve aspect ratio.
#
# **Status:** stub — implement `src/processor.py` before running.

# %%
import sys
from pathlib import Path

repo_root = Path().resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from src.config_loader import load_config
from src.processor import process_patent

cfg = load_config()
raw_dir  = cfg['paths']['raw_images']
proc_dir = cfg['paths']['processed']
print(f"raw_images : {raw_dir}")
print(f"processed  : {proc_dir}")
print(f"target_size: {cfg['processing']['target_size']}")

# %%
from src.processor import process_patent as proc_patent
from tqdm import tqdm

patent_dirs = sorted([d for d in raw_dir.iterdir() if d.is_dir()])
total = 0
for d in tqdm(patent_dirs, desc="Stage 02"):
    n = proc_patent(d.name, cfg)
    total += n
    if n:
        print(f"  {d.name}: {n} images processed")

print(f"\nTotal images processed: {total}")
