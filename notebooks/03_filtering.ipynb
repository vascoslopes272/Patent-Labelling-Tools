# %% [markdown]
# # Stage 03 — Filtering (stub)
#
# Removes blank pages, undersized images, and near-duplicate drawings
# before feeding the corpus to DINOv2.
#
# **Status:** stub — implement `src/filtering.py` before running.

# %%
import sys
from pathlib import Path

repo_root = Path().resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from src.config_loader import load_config
from src.filtering import filter_patent

cfg = load_config()
proc_dir = cfg['paths']['processed']
print(f"processed: {proc_dir}")

# %%
# TODO: uncomment when filtering.py is implemented
#
# for patent_dir in sorted(proc_dir.iterdir()):
#     if not patent_dir.is_dir():
#         continue
#     kept = filter_patent(patent_dir.name, cfg)
#     print(f"{patent_dir.name}: {len(kept)} images kept")

print('Stage 03 not yet implemented — see src/filtering.py')
